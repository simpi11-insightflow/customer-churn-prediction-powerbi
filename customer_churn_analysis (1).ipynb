# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\simpi\Desktop\Customer Retention Optimization System\final_customer_churn.csv")

# %%
df.head()
# Out:
#    customerid  count        country       state         city  zip_code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#     latitude   longitude  gender senior_citizen  ...        contract  \
# 0  33.964131 -118.272783    Male             No  ...  Month-to-month
# 1  34.059281 -118.307420  Female             No  ...  Month-to-month
# 2  34.048013 -118.293953  Female             No  ...  Month-to-month
# 3  34.062125 -118.315709  Female             No  ...  Month-to-month
# 4  34.039224 -118.266293    Male             No  ...  Month-to-month
#
#   paperless_billing             payment_method monthly_charges total_charges  \
# ...

# %%
df.shape
# Out:
# (7043, 32)

# %%
df.columns
# Out:
# Index(['customerid', 'count', 'country', 'state', 'city', 'zip_code',
#        'latitude', 'longitude', 'gender', 'senior_citizen', 'partner',
#        'dependents', 'tenure', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'contract', 'paperless_billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn_label', 'churn_value', 'churn_score', 'cltv',
#        'churn_reason'],
#       dtype='str')

# %%
df.dtypes
# Out:
# customerid               str
# count                  int64
# country                  str
# state                    str
# city                     str
# zip_code               int64
# latitude             float64
# longitude            float64
# gender                   str
# senior_citizen           str
# partner                  str
# dependents               str
# tenure                 int64
# phone_service            str
# multiple_lines           str
# internet_service         str
# online_security          str
# online_backup            str
# device_protection        str
# tech_support             str
# streaming_tv             str
# streaming_movies         str
# contract                 str
# paperless_billing        str
# payment_method           str
# monthly_charges      float64
# total_charges        float64
# churn_label              str
# churn_value            int64
# churn_score            int64
# cltv                   int64
# churn_reason             str
# ...

# %%
df.isnull().sum()
# Out:
# customerid              0
# count                   0
# country                 0
# state                   0
# city                    0
# zip_code                0
# latitude                0
# longitude               0
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# tenure                  0
# phone_service           0
# multiple_lines          0
# internet_service        0
# online_security         0
# online_backup           0
# device_protection       0
# tech_support            0
# streaming_tv            0
# streaming_movies        0
# contract                0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges          11
# churn_label             0
# churn_value             0
# churn_score             0
# cltv                    0
# churn_reason         5174
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         count      zip_code     latitude    longitude       tenure  \
# count  7043.0   7043.000000  7043.000000  7043.000000  7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880    32.371149
# std       0.0   1865.794555     2.455723     2.157889    24.559481
# min       1.0  90001.000000    32.555828  -124.301372     0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412     9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885    29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237    55.000000
# max       1.0  96161.000000    41.962127  -114.192901    72.000000
#
#        monthly_charges  total_charges  churn_value  churn_score         cltv
# count      7043.000000    7032.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692    2283.300441     0.265370    58.699418  4400.295755
# std          30.090047    2266.771362     0.441561    21.525131  1183.057152
# ...

# %%
# Customer Churn Distribution
sns.countplot(x='churn_label', data=df)

plt.title("Customer Churn Distribution")

plt.show()

# %%
# Gender vc Churn
sns.countplot(x='gender', hue='churn_label', data=df)

plt.title("Gender vs Churn")

plt.show()

# %%
# Senior Citizen vs Churn
sns.countplot(x='senior_citizen', hue='churn_label', data=df)

plt.title("Senior Citizen vs Churn")

plt.show()

# %%
# Partner vs Churn
sns.countplot(x='partner', hue='churn_label', data=df)

plt.title("Partner vs Churn")

plt.show()

# %%
# Dependents vs Churn
sns.countplot(x='dependents', hue='churn_label', data=df)

plt.title("Dependents vs Churn")

plt.show()

# %%
# Contract Type vs Churn
sns.countplot(x='contract', hue='churn_label', data=df)

plt.title("Contract Type vs Churn")

plt.xticks(rotation=15)

plt.show()

# %%
# Internet Services vs Churn
sns.countplot(x='internet_service', hue='churn_label', data=df)

plt.title("Internet Service vs Churn")

plt.show()

# %%
# PAyment Method vs Churn
sns.countplot(x='payment_method', hue='churn_label', data=df)

plt.title("Payment Method vs Churn")

plt.xticks(rotation=45)

plt.show()

# %%
# Monthly Charges Distribution
sns.histplot(df['monthly_charges'], kde=True)

plt.title("Monthly Charges Distribution")

plt.show()

# %%
# Monthly Charges vs Churn
sns.boxplot(x='churn_label', y='monthly_charges', data=df)

plt.title("Monthly Charges vs Churn")

plt.show()

# %%
# Customer Tenure Distribution
sns.histplot(df['tenure'], kde=True)

plt.title("Customer Tenure Distribution")

plt.show()

# %%
# Tenure vs Churn
sns.boxplot(x='churn_label', y='tenure', data=df)

plt.title("Tenure vs Churn")

plt.show()

# %%
# Correlation Matrix
correlation = df.corr(numeric_only=True)

correlation
# Out:
#                  count  zip_code  latitude  longitude    tenure  \
# count              NaN       NaN       NaN        NaN       NaN
# zip_code           NaN  1.000000  0.895743  -0.784271  0.001041
# latitude           NaN  0.895743  1.000000  -0.876779 -0.001631
# longitude          NaN -0.784271 -0.876779   1.000000 -0.001678
# tenure             NaN  0.001041 -0.001631  -0.001678  1.000000
# monthly_charges    NaN -0.004596 -0.019899   0.024098  0.247900
# total_charges      NaN -0.001462 -0.010313   0.009047  0.825880
# churn_value        NaN  0.003346 -0.003384   0.004594 -0.352229
# churn_score        NaN -0.002769 -0.007684   0.004260 -0.224987
# cltv               NaN -0.003562  0.000886   0.000485  0.396406
#
#                  monthly_charges  total_charges  churn_value  churn_score  \
# count                        NaN            NaN          NaN          NaN
# zip_code               -0.004596      -0.001462     0.003346    -0.002769
# ...

# %%
#Correlation Heatmap
plt.figure(figsize=(10,6))

sns.heatmap(correlation, annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %%
# Top Churn Reasons
plt.figure(figsize=(10,6))

df['churn_reason'].value_counts().head(10).plot(kind='bar')

plt.title("Top Churn Reasons")

plt.xlabel("Reason")

plt.ylabel("Count")

plt.xticks(rotation=45)

plt.show()

# %%
# Create tenure group
df['tenure_group'] = pd.cut(
    df['tenure'],
    bins=[0,12,24,48,72],
    labels=['0-1 Year','1-2 Years','2-4 Years','4+ Years']
)

# %%
# Create Revenue Segment
df['revenue_segment'] = pd.qcut(
    df['monthly_charges'],
    q=4,
    labels=['Low','Medium','High','Premium']
)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
ml_df=df.copy()

# %%
#Encode target variable
le= LabelEncoder()
ml_df['churn_label']=le.fit_transform(ml_df['churn_label'])

# %%
ml_df['churn_label'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: churn_label, dtype: int64

# %%
# Feature selection + encoding 
# Remove unnecessary column
X=ml_df.drop(['customerid','churn_label','churn_reason'],axis=1)
Y=ml_df['churn_label']

# %%
X.head()
# Out:
#    count        country       state         city  zip_code   latitude  \
# 0      1  United States  California  Los Angeles     90003  33.964131
# 1      1  United States  California  Los Angeles     90005  34.059281
# 2      1  United States  California  Los Angeles     90006  34.048013
# 3      1  United States  California  Los Angeles     90010  34.062125
# 4      1  United States  California  Los Angeles     90015  34.039224
#
#     longitude  gender senior_citizen partner  ...        contract  \
# 0 -118.272783    Male             No      No  ...  Month-to-month
# 1 -118.307420  Female             No      No  ...  Month-to-month
# 2 -118.293953  Female             No      No  ...  Month-to-month
# 3 -118.315709  Female             No     Yes  ...  Month-to-month
# 4 -118.266293    Male             No      No  ...  Month-to-month
#
#    paperless_billing             payment_method monthly_charges total_charges  \
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: churn_label, dtype: int64

# %%
ml_df.select_dtypes(include='object').columns
# Out:
# C:\Users\simpi\AppData\Local\Temp\ipykernel_20428\1268495674.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   ml_df.select_dtypes(include='object').columns
# Index(['customerid', 'country', 'state', 'city', 'gender', 'senior_citizen',
#        'partner', 'dependents', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'contract', 'paperless_billing', 'payment_method', 'churn_reason'],
#       dtype='str')

# %%
for col in ml_df.select_dtypes(include='object').columns:
    ml_df[col]=le.fit_transform(ml_df[col])
# Out:
# C:\Users\simpi\AppData\Local\Temp\ipykernel_20428\1175465590.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in ml_df.select_dtypes(include='object').columns:

# %%
ml_df.head()
# Out:
#    customerid  count  country  state  city  zip_code   latitude   longitude  \
# 0        2564      1        0      0   562     90003  33.964131 -118.272783
# 1        6511      1        0      0   562     90005  34.059281 -118.307420
# 2        6551      1        0      0   562     90006  34.048013 -118.293953
# 3        5604      1        0      0   562     90010  34.062125 -118.315709
# 4         174      1        0      0   562     90015  34.039224 -118.266293
#
#    gender  senior_citizen  ...  payment_method  monthly_charges  \
# 0       1               0  ...               3            53.85
# 1       0               0  ...               2            70.70
# 2       0               0  ...               2            99.65
# 3       0               0  ...               2           104.80
# 4       1               0  ...               0           103.70
#
#    total_charges  churn_label  churn_value  churn_score  cltv  churn_reason  \
# ...

# %%
print(ml_df[['tenure_group','revenue_segment']].dtypes)
# Out:
# tenure_group       category
# revenue_segment    category
# dtype: object

# %%
ml_df['tenure_group']=ml_df['tenure_group'].cat.codes
ml_df['revenue_segment']=ml_df['revenue_segment'].cat.codes

# %%
ml_df.head()
# Out:
#    customerid  count  country  state  city  zip_code   latitude   longitude  \
# 0        2564      1        0      0   562     90003  33.964131 -118.272783
# 1        6511      1        0      0   562     90005  34.059281 -118.307420
# 2        6551      1        0      0   562     90006  34.048013 -118.293953
# 3        5604      1        0      0   562     90010  34.062125 -118.315709
# 4         174      1        0      0   562     90015  34.039224 -118.266293
#
#    gender  senior_citizen  ...  payment_method  monthly_charges  \
# 0       1               0  ...               3            53.85
# 1       0               0  ...               2            70.70
# 2       0               0  ...               2            99.65
# 3       0               0  ...               2           104.80
# 4       1               0  ...               0           103.70
#
#    total_charges  churn_label  churn_value  churn_score  cltv  churn_reason  \
# ...

# %%
ml_df=pd.get_dummies(ml_df,drop_first=True)

# %%
#train test split tu yaat hobo laage
# Train test split
X_train,X_test,Y_train,Y_test=train_test_split(
    X,Y,test_size=0.2,random_state=42
)

# %%
X_train.dtypes
# Out:
# count                   int64
# country                   str
# state                     str
# city                      str
# zip_code                int64
# latitude              float64
# longitude             float64
# gender                    str
# senior_citizen            str
# partner                   str
# dependents                str
# tenure                  int64
# phone_service             str
# multiple_lines            str
# internet_service          str
# online_security           str
# online_backup             str
# device_protection         str
# tech_support              str
# streaming_tv              str
# streaming_movies          str
# contract                  str
# paperless_billing         str
# payment_method            str
# monthly_charges       float64
# total_charges         float64
# churn_value             int64
# churn_score             int64
# cltv                    int64
# tenure_group         category
# revenue_segment      category
# ...

# %%
# Check Shapes
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (5634, 31)
# (1409, 31)
# (5634,)
# (1409,)

# %%
X_train.select_dtypes(exclude=['int64','float64','bool']).columns
# Out:
# Index(['country', 'state', 'city', 'gender', 'senior_citizen', 'partner',
#        'dependents', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract', 'paperless_billing',
#        'payment_method', 'tenure_group', 'revenue_segment'],
#       dtype='str')

# %%
ml_df=pd.get_dummies(ml_df,columns=['tenure_group','revenue_segment'],drop_first=True)

# %%
ml_df.columns
# Out:
# Index(['customerid', 'count', 'country', 'state', 'city', 'zip_code',
#        'latitude', 'longitude', 'gender', 'senior_citizen', 'partner',
#        'dependents', 'tenure', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'contract', 'paperless_billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn_label', 'churn_value', 'churn_score', 'cltv',
#        'churn_reason', 'tenure_group_0', 'tenure_group_1', 'tenure_group_2',
#        'tenure_group_3', 'revenue_segment_1', 'revenue_segment_2',
#        'revenue_segment_3'],
#       dtype='str')

# %%
ml_df=pd.get_dummies(ml_df,drop_first=True)

# %%
ml_df.dtypes
# Out:
# customerid             int64
# count                  int64
# country                int64
# state                  int64
# city                   int64
# zip_code               int64
# latitude             float64
# longitude            float64
# gender                 int64
# senior_citizen         int64
# partner                int64
# dependents             int64
# tenure                 int64
# phone_service          int64
# multiple_lines         int64
# internet_service       int64
# online_security        int64
# online_backup          int64
# device_protection      int64
# tech_support           int64
# streaming_tv           int64
# streaming_movies       int64
# contract               int64
# paperless_billing      int64
# payment_method         int64
# monthly_charges      float64
# total_charges        float64
# churn_label            int64
# churn_value            int64
# churn_score            int64
# cltv                   int64
# churn_reason           int64
# ...

# %%
ml_df.isnull().sum()
# Out:
# customerid            0
# count                 0
# country               0
# state                 0
# city                  0
# zip_code              0
# latitude              0
# longitude             0
# gender                0
# senior_citizen        0
# partner               0
# dependents            0
# tenure                0
# phone_service         0
# multiple_lines        0
# internet_service      0
# online_security       0
# online_backup         0
# device_protection     0
# tech_support          0
# streaming_tv          0
# streaming_movies      0
# contract              0
# paperless_billing     0
# payment_method        0
# monthly_charges       0
# total_charges        11
# churn_label           0
# churn_value           0
# churn_score           0
# cltv                  0
# churn_reason          0
# tenure_group_0        0
# tenure_group_1        0
# tenure_group_2        0
# tenure_group_3        0
# revenue_segment_1     0
# revenue_segment_2     0
# ...

# %%
X=ml_df.drop(['customerid','churn_label','churn_value','churn_score','churn_reason'],axis=1)
Y=ml_df['churn_label']

# %%
X=X.fillna(0)

# %%
#aitu uporole move koribo lagibo
# Train test split
X_train,X_test,Y_train,Y_test=train_test_split(
    X,Y,test_size=0.2,random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
ml_df.isnull().sum()
# Out:
# customerid            0
# count                 0
# country               0
# state                 0
# city                  0
# zip_code              0
# latitude              0
# longitude             0
# gender                0
# senior_citizen        0
# partner               0
# dependents            0
# tenure                0
# phone_service         0
# multiple_lines        0
# internet_service      0
# online_security       0
# online_backup         0
# device_protection     0
# tech_support          0
# streaming_tv          0
# streaming_movies      0
# contract              0
# paperless_billing     0
# payment_method        0
# monthly_charges       0
# total_charges        11
# churn_label           0
# churn_value           0
# churn_score           0
# cltv                  0
# churn_reason          0
# tenure_group_0        0
# tenure_group_1        0
# tenure_group_2        0
# tenure_group_3        0
# revenue_segment_1     0
# revenue_segment_2     0
# ...

# %%
ml_df=ml_df.dropna()

# %%
X=ml_df.drop(['customerid','churn_label','churn_value','churn_score','churn_reason'],
             axis=1)
Y=ml_df['churn_label']

# %%
# Train test split
X_train,X_test,Y_train,Y_test=train_test_split(
    X,Y,test_size=0.2,random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
model=LogisticRegression(max_iter=1000)
model.fit(X_train_scaled,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred=model.predict(X_test_scaled)

# %%
#accuracy
accuracy=accuracy_score(Y_test,Y_pred)
print(accuracy)
# Out:
# 0.814498933901919

# %%
# Confusion matrix
cm=confusion_matrix(Y_test,Y_pred)
print(cm)
# Out:
# [[926  86]
#  [175 220]]

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1012
#            1       0.72      0.56      0.63       395
#
#     accuracy                           0.81      1407
#    macro avg       0.78      0.74      0.75      1407
# weighted avg       0.81      0.81      0.81      1407

# %%
#Feature important analysis
feature_importance=pd.DataFrame({
    'Feature':X_train.columns,
    'Coefficient':model.coef_[0]
})
feature_importance=feature_importance.sort_values(
    by='Coefficient',ascending=False 
)
print(feature_importance.head(10))
# Out:
#               Feature  Coefficient
# 24    monthly_charges     0.517869
# 25      total_charges     0.472037
# 33  revenue_segment_3     0.198010
# 30     tenure_group_3     0.188590
# 22  paperless_billing     0.187859
# 14   internet_service     0.187850
# 9             partner     0.163561
# 32  revenue_segment_2     0.147965
# 31  revenue_segment_1     0.140340
# 13     multiple_lines     0.113971

# %%
# Creating Feature Importance graph
top_features=feature_importance.head(10)
plt.figure(figsize=(10,6))
plt.barh(top_features['Feature'],
         top_features['Coefficient'])
plt.xlabel("Coefficient Value")
plt.ylabel("Features")
plt.title("Top Features Affecting Customer Churn")
plt.gca().invert_yaxis()
plt.show()

# %%
# Creating prediction column in python
predictions=model.predict(X_test_scaled)

# %%
df['Predicted_churn']=0

# %%
df.loc[X_test.index,'Predicted_Churn']=predictions

# %%
df.to_csv("customer_churn_final_dashboard.csv",index=False)
